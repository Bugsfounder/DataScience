# %%
import matplotlib.pyplot as plt
import numpy as np
x = [1,2,3,4]
y = [5,6,7,8]
plt.plot(x,y)

# %%
data_x = np.linspace(1,9,30)
data_y = np.linspace(5,12,30)

data_x_2 = np.linspace(4,9,40)
data_y_2 = np.linspace(3,10,40)

x = np.linspace(0,10,100)
y = np.sin(x)

x2 = np.linspace(3,20,100)
y2 = np.sin(x2)

plt.plot(data_x,data_y)
plt.plot(data_x_2,data_y_2)
plt.plot(x,y)
plt.plot(x2,y2)

# %%
plt.bar(['manisha','raja','nabin'],[98,50,30])
plt.show()  # not compulsary in jupyter

# %%
plt.scatter(x,y)

# %%
plt.boxplot(x)
# plt.boxplot(data_x_2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x74f3410f81d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x74f3410f8650>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x74f3410c3f20>],
#  'medians': [<matplotlib.lines.Line2D at 0x74f3410f8b90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x74f3410f8e90>],
#  'means': []}
