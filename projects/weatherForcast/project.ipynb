# %%
import pandas as pd
import numpy as np 
# import matplotlib as plt
# import seaborn as sns 

data = pd.read_csv('./weather.csv')

data.head()
# Out:
#            latitude            longitude                elevation  \
# 0          52.54833            13.407822                     38.0
# 1              time  temperature_2m (°C)  weather_code (wmo code)
# 2  2025-05-26T00:00                 12.5                        1
# 3  2025-05-26T01:00                 12.5                        1
# 4  2025-05-26T02:00                 12.1                        2
#
#       utc_offset_seconds   timezone timezone_abbreviation
# 0                      0        GMT                   GMT
# 1  wind_speed_10m (km/h)  rain (mm)                   NaN
# 2                   10.1       0.00                   NaN
# 3                    9.0       0.00                   NaN
# 4                   10.1       0.00                   NaN

# %%
import pandas as pd
import plotly.express as px

# Load your data
df = pd.read_csv('./weather.csv')

# Create a scatter mapbox plot
fig = px.scatter_map(
    df,
    lat="latitude",
    lon="longitude",
    hover_name="city",
    hover_data=["temperature_c", "humidity"],
    color="temperature_c",
    color_continuous_scale="Turbo",
    size_max=15,
    zoom=4,
    height=700
)

# Use an open Mapbox style (no token needed for 'open-street-map')

fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

fig.show()
df
# Out:
#                   city  latitude  longitude  temperature_c  humidity
# 0              Roorkee   29.8670    77.8940           32.1        60
# 1                Delhi   28.6139    77.2090           35.2        55
# 2               Mumbai   19.0760    72.8777           30.4        80
# 3              Chennai   13.0827    80.2707           33.0        75
# 4              Kolkata   22.5726    88.3639           31.7        78
# 5            Bengaluru   12.9716    77.5946           28.5        65
# 6            Hyderabad   17.3850    78.4867           31.2        68
# 7            Ahmedabad   23.0225    72.5714           34.5        50
# 8               Jaipur   26.9124    75.7873           36.0        45
# 9              Lucknow   26.8467    80.9462           33.8        58
# 10              Bhopal   23.2599    77.4126           32.4        62
# 11               Patna   25.5941    85.1376           34.1        70
# 12                Pune   18.5204    73.8567           29.6        72
# 13              Nagpur   21.1458    79.0882           35.0        52
# 14  Thiruvananthapuram    8.5241    76.9366           29.2        85
# 15       Visakhapatnam   17.6868    83.2185           31.3        76
# 16               Surat   21.1702    72.8311           32.7        69
# 17              Kanpur   26.4499    80.3319           34.4        60
# 18            Ludhiana   30.9010    75.8573           33.2        57
# 19                Agra   27.1767    78.0081           36.3        49
# 20            Vadodara   22.3072    73.1812           33.5        54
# 21              Nashik   20.0059    73.7646           30.2        66
# 22           Faridabad   28.4089    77.3178           35.6        53
# 23              Meerut   28.9845    77.7064           34.9        55
# 24              Rajkot   22.3039    70.8022           35.1        48
# 25            Varanasi   25.3176    82.9739           34.6        61
# 26            Srinagar   34.0837    74.7973           21.0        50
# 27            Amritsar   31.6340    74.8723           32.2        55
# 28              Ranchi   23.3441    85.3096           30.9        72
# 29            Guwahati   26.1445    91.7362           31.0        77
# 30             Jodhpur   26.2389    73.0243           37.0        40
# 31             Madurai    9.9252    78.1198           32.0        74
# 32              Raipur   21.2514    81.6296           33.6        67
# 33             Gwalior   26.2183    78.1828           35.4        52
# 34            Jabalpur   23.1815    79.9864           34.2        58
# 35          Coimbatore   11.0168    76.9558           30.0        70
# 36         Bhubaneswar   20.2961    85.8245           32.8        73
# 37            Warangal   17.9784    79.5941           33.1        69
# 38            Amravati   20.9374    77.7796           34.0        61
# 39             Solapur   17.6599    75.9064           33.8        65
# 40               Hubli   15.3647    75.1240           31.7        68
# 41     Tiruchirappalli   10.7905    78.7047           32.4        72
# 42            Bareilly   28.3670    79.4304           33.9        56
# 43           Moradabad   28.8386    78.7733           34.1        57
# 44             Panipat   29.3909    76.9635           35.7        54
# 45            Bilaspur   22.0797    82.1391           32.6        66
# 46             Udaipur   24.5854    73.7125           34.3        53
# 47              Shimla   31.1048    77.1734           22.5        60
# 48            Dehradun   30.3165    78.0322           29.4        64
# 49           Mangalore   12.9141    74.8560           30.6        78
# 50              Guntur   16.3067    80.4365           33.3        74
# 51             Dhanbad   23.7957    86.4304           33.2        68
# 52             Nellore   14.4426    79.9865           32.9        73
# 53            Jamnagar   22.4707    70.0577           33.7        59
# 54               Noida   28.5355    77.3910           35.0        55
# 55           Ghaziabad   28.6692    77.4538           34.8        56
