# %%
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Generate sample
data = np.random.seed(42)
X = np.random.randn(100, 1)
y = 2 * X.flatten() + 1 + np.random.randn(100) * 0.5
# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Train model
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Calculate MSE
mse = mean_squared_error(y_test, y_pred)
print(f"MSE: {mse:.4f}")
# Manual calculation
mse_manual = np.mean((y_test - y_pred) ** 2)
print(f"MSE (manual): {mse_manual:.4f}")
# Out:
# MSE: 0.2135
# MSE (manual): 0.2135

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
# Continuing from previous example
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"RMSE: {rmse:.4f}")
# Manual calculation
rmse_manual = np.sqrt(np.mean((y_test - y_pred) ** 2))
print(f"RMSE (manual): {rmse_manual:.4f}")
# # Interpretation example
print(f"On average, predictions are off by ±{rmse:.2f} units")
# # Compare with actual values
print(f"Actual values range: {y_test.min():.2f} to {y_test.max():.2f}")
print(f"RMSE as % of range: {rmse/(y_test.max()-y_test.min())*100:.1f}%")
# Out:
# RMSE: 0.4620
# RMSE (manual): 0.4620
# On average, predictions are off by ±0.46 units
# Actual values range: -1.83 to 4.74
# RMSE as % of range: 7.0%
