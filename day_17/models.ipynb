# %%
import tensorflow as tf
from tensorflow.keras import Sequential, layers
import numpy as np

# Data

X = np.array([1, 2, 3, 4, 5], dtype=float)
y = np.array([2, 4, 6, 8, 10], dtype=float)

# Model
model = Sequential([layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mse')
model.fit(X, y, epochs=10, verbose=0)

# Prediction
# print(model.predict([6]))  # Output: ~[12.]

# %%
from tensorflow.keras.layers import Dense

# Data
X = np.array([[0], [1], [2], [3], [4]])
y = np.array([[0], [0], [1], [1], [1]])  # Binary labels

# Model
model = Sequential([Dense(1, input_shape=[1], activation='sigmoid')])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X, y, epochs=100, verbose=0)

# print(model.predict([[1.5]]))  # Probability output

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

model.fit(X, y, epochs=1000, 
          validation_split=0.2,
          callbacks=[early_stop])
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.2500 - loss: 1.5733 - val_accuracy: 0.0000e+00 - val_loss: 4.1106
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.2500 - loss: 1.5720 - val_accuracy: 0.0000e+00 - val_loss: 4.1061
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.2500 - loss: 1.5708 - val_accuracy: 0.0000e+00 - val_loss: 4.1016
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.2500 - loss: 1.5696 - val_accuracy: 0.0000e+00 - val_loss: 4.0973
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.2500 - loss: 1.5684 - val_accuracy: 0.0000e+00 - val_loss: 4.0930
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.2500 - loss: 1.5672 - val_accuracy: 0.0000e+00 - val_loss: 4.0889
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.2500 - loss: 1.5661 - val_accuracy: 0.0000e+00 - val_loss: 4.0849
# Epoch 8/1000
# ...

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=[10]),
    Dense(32, activation='relu'),
    Dense(1)
])

# %%
from tensorflow.keras.layers import Normalization

norm = Normalization()
# norm.adapt(X_train)  # Learn statistics
model.add(norm)  # First layer

# %%
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50
)

# %%
def huber_loss(y_true, y_pred):
    threshold = 1
    error = y_true - y_pred
    return tf.reduce_mean(
        tf.where(tf.abs(error) < threshold, 
                0.5 * tf.square(error),
                threshold * (tf.abs(error) - 0.5 * threshold))
    )

model.compile(optimizer='adam', loss=huber_loss)

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.2f}")
predictions = model.predict(X_new, batch_size=32)
model.save_weights('weights.h5')
new_model.load_weights('weights.h5')
